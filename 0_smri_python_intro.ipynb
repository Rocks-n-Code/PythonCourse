# %% [markdown]
# <a href="https://colab.research.google.com/github/Rocks-n-Code/PythonCourse/blob/master/0_smri_python_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
# <sub><sub>*Given by Agapito Associates, LLC on September 27, 2026 for SMRI Fall 2026.*</sub></sub>
#
# <table style="position: absolute; top: 0; bottom: 0; left: 0; right: 0;">
#   <tr style="width: 100%; font-size: 24px;">
#     <td><img src="https://raw.githubusercontent.com/Rocks-n-Code/PythonCourse/refs/heads/master/img/SMRI.svg" height="200"></td>
#     <td><h1 style="margin:0;"> Introduction to Python
# for Technical Professionals </h1></td>
#   <td><td/>
#   <tr/>
# </table>
#
# ---
# **Schedule**
#
# 08:00 - 17:00
#
# Breaks:
# - 10:00 - 10:30 Morning Break
# - 12:00 - 13:00 Lunch, <sup><sub><sub>*come back early if you want help with a local python install*</sub></sub></sup>
# - 15:00 - 15:30 Afternoon Break
#
#
# ___
# **Instructor**
#
#
# [Matthew W. Bauer, P.G.](mailto:bauer@agapito.com)
#
# *Your guest geologist with a python habit for the day.*
#
#
# <a href="https://www.linkedin.com/in/matthewbauerpg/">
# <img src="https://thumb.wikimedia.org/wikipedia/commons/thumb/8/81/LinkedIn_icon.svg/120px-LinkedIn_icon.svg.png?utm_source=commons.wikimedia.org&utm_campaign=index&utm_content=thumbnail" width="25" height="25">
# <a/>
#
# <a href="https://www.rmag.org/">
# <img src="https://www.rmag.org/graphics/design/RMAG-logo-2022.png" width="25" height="25">
# <a/>
#
# <a href="https://www.agapito.com/team/matthew-bauer/">
# <img src="https://raw.githubusercontent.com/Rocks-n-Code/PythonCourse/refs/heads/master/img/AAI%20Logo_Pants%20Only_2026.svg" height="25">
# <a/>
#
# ---
#
# **Rules for the Class**
# <img align="right" src="https://github.com/Rocks-n-Code/PythonCourse/blob/master/img/suck_at_something_new.jpg?raw=true" width="300">
# 1. Take time.
#
#
# 2. Be nice.
#
#
# 3. But most of all... ...Have fun!
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# ---
#
# So let's start with some fun...

# %%
# %%html
# <iframe width="1000" height="260"
# src="https://www.youtube.com/embed/MmiTWQMngFw?playlist=MmiTWQMngFw&loop=1;controls=0"
# title="YouTube video player"
# frameborder="0"
# allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share"
# referrerpolicy="strict-origin-when-cross-origin"
# rel=0
# modestbranding=1
# controls=0
# allowfullscreen>
# </iframe>
# Out:
# <iframe width="1000" height="260"
# src="https://www.youtube.com/embed/MmiTWQMngFw?playlist=MmiTWQMngFw&loop=1;controls=0"
# title="YouTube video player"
# frameborder="0"
# allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share"
# referrerpolicy="strict-origin-when-cross-origin"
# rel=0
# modestbranding=1
# controls=0
# allowfullscreen>
# </iframe>

# %% [markdown]
# <sub>Want to make your own? Check out https://github.com/ColCarroll/ridge_map</sub>
#
#
# ---
#
# <img align="right" style="padding-right: 25px;" src="https://devhumor.com/content/uploads/images/May2025/vibe_debugging.jpeg" width="300" >
#
# &nbsp;&nbsp;&nbsp;&nbsp;We will spend this morning with basic syntax and pandas then walk through some applied examples specific to salt cavern operations. These days with LLMs the barrier to entry for using code is significantly lower. Understanding syntax and basics will help you debug code.
#
#
# Considering the time avalible today we will be using Google Colab for the notebooks. Installing Python is recommended from the [Anaconda distribution.](https://www.anaconda.com/download/success?reg=skipped)
#
#
# Windows users will need to add these to the system environmental variable `Path`:
#
# - C:\\Where you installed python\\Anaconda3
# - C:\\Where you installed python\\Anaconda3\\Scripts
# - C:\\Where you installed python\\Anaconda3\\Library\\bin
#
# I'll help folks over the lunch break but if you need help on an install in the future? Watch [this](https://youtu.be/KUuoFRye37w) video.
#
# ---
#
# ## Notebooks
#
# [0 - Intro]()
#
# [1 - Basic Python Syntax](https://colab.research.google.com/github/Rocks-n-Code/PythonCourse/blob/master/1%20-%20Basic%20Python%20Syntax.ipynb)
#
# [2 - Loops, Logic, & Functions](https://colab.research.google.com/github/Rocks-n-Code/PythonCourse/blob/master/2%20-%20Loops%2C%20Logic%2C%20%26%20Functions.ipynb)
#
# [3 - Pandas & Matplotlib](https://colab.research.google.com/github/Rocks-n-Code/PythonCourse/blob/master/3%20-%20Pandas%20%26%20Matplotlib.ipynb)
#
# [6 - Scraping Data](https://colab.research.google.com/github/Rocks-n-Code/PythonCourse/blob/master/6%20-%20Scraping%20Data.ipynb)
#
# [7 - Log Facies with Unsupervised Machine Learning](https://colab.research.google.com/github/Rocks-n-Code/PythonCourse/blob/master/7%20-%20UnSupML_LogFacies%20.ipynb)
#
# [8 - Supervised Machine Learning: Random Forest Regressor Building and Mineral model from a Pulsed Neutron Log.](https://colab.research.google.com/github/Rocks-n-Code/PythonCourse/blob/master/8%20-%20SupML_RF_Lithology.ipynb)
#
# [9 - Salt Cavern Workflows: Well Spot, Deviation Survey, & Sonars](https://colab.research.google.com/github/Rocks-n-Code/PythonCourse/blob/master/Salt_Cavern_Workflows.ipynb)
#
# [<Back](https://github.com/Rocks-n-Code/PythonCourse) [Next>](https://colab.research.google.com/github/Rocks-n-Code/PythonCourse/blob/master/1%20-%20Basic%20Python%20Syntax.ipynb)
